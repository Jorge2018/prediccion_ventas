# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge2018/prediccion_ventas/blob/main/Bike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
bike_df= pd.read_excel(r'/content/RailsToTrails_National Count Data_week.xlsx')
filtro_fecha = (bike_df['Week of'] > '2020-07-31') 
bike_df_fecha=bike_df.loc[filtro_fecha]
#bike_df_fecha  #### este df muestra los datos filtrados mayores al 31-07
filtro_porc = (bike_df['Change 2019-2020'] > 1.00) 
bike_df_porc=bike_df.loc[filtro_porc]
#bike_df_porc  #### este df muestra los datos filtrados mayores al 100 %
bike_df_00 = pd.concat([bike_df_porc, bike_df_fecha], axis=0) #une los dos df recien creados
bike_df_00
# Out:
# Mounted at /content/drive
#    Timeframe    Week of   2019 counts (31 counters)  \
# 7     Week 8 2020-02-17                     69492.0
# 11   Week 12 2020-03-16                    125440.0
# 12   Week 13 2020-03-23                    136330.0
# 13   Week 14 2020-03-30                    118784.0
# 14   Week 15 2020-04-06                    132033.0
# 0     Week 1 2020-12-30                    167679.0
# 31   Week 32 2020-08-03                    180605.0
# 32   Week 33 2020-08-10                    191450.0
# 33   Week 34 2020-08-17                    168754.0
# 34   Week 35 2020-08-24                    176624.0
# 35   Week 36 2020-08-31                    184806.0
# 36   Week 37 2020-09-07                    157345.0
# 37   Week 38 2020-09-14                    152527.0
# 38   Week 39 2020-09-21                    141072.0
# 39   Week 40 2020-09-28                    135881.0
# 40   Week 41 2020-10-05                    132239.0
# ...

# %%
boston_df= pd.read_csv(r'https://raw.githubusercontent.com/Jorge2018/prediccion_ventas/main/bostonHousing1978.csv')
boston_df.head()
# Out:
#       RM  LSTAT  PTRATIO  target
# 0  6.575   4.98     15.3    24.0
# 1  6.421   9.14     17.8    21.6
# 2  7.185   4.03     17.8    34.7
# 3  6.998   2.94     18.7    33.4
# 4  7.147   5.33     18.7    36.2

# %%
url_df=pd.read_csv(r'https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data')
#url_df.head() # muestra los primeros 5
#url_df.tail() # muestra los ultimos 5
#url_df.dtypes # verifica tipos de datos
#url_df.shape # retorna num de filas y col del df (en ese orden)
#url_df.info() # retorna tipos de datos y si existen valores null
url_df[['7']] # esto es un df
url_df['7'] # esto es una serie
url_df['7'][0:10]# crea una serie (similar a las listas) con los 10 primeros filas (0 al 9)
url_df.loc[0:10,['7']] # captura las primeras 10 filas de la columna 7 (0 al 10)
# Out:
#        7
# 0      9
# 1      7
# 2      9
# 3      7
# 4      9
# ...   ..
# 10074  9
# 10075  7
# 10076  9
# 10077  7
# 10078  9
#
# [10079 rows x 1 columns]

# %%
import numpy as np
titanic_df= pd.read_csv(r'https://raw.githubusercontent.com/Jorge2018/prediccion_ventas/main/titanic.csv')

#titanic_df.info() # pto 2
#titanic_df.head(10) # pto 2
#titanic_df.tail(10)  # pto 2
filtro= (titanic_df['PassengerId']==148) 
titanic_df_filtro=titanic_df.loc[filtro]
#titanic_df_filtro # pto 3
#titanic_df[::2] # pto 4
filtro_class= (titanic_df['Pclass']==1) 
titanic_df_filtro_class=titanic_df.loc[filtro_class]
#titanic_df_filtro_class['Name'].sort_values() # pto 5
#print('el porcentaje de supervivientes es' ,titanic_df['Survived'].mean() * 100) # pto 6
#titanic_df.groupby('Pclass').mean()[['Survived']] # pto 7
titanic_df[['Age']].dropna() # pto 8
titanic_df[['Age']]
#filtro_woman= (titanic_df['Sex']=='female') 
#titanic_df_filtro_woman=titanic_df.loc(filtro_woman & filtro_class)
#titanic_df_filtro_woman[['Sex']]
#titanic_df['Edad_Boolean']=np.where(titanic_df['Age'] > 18.0, True, False)
titanic_df
#print(titanic.groupby(['Pclass','Sex'])['Age'].mean().unstack()['female'])
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]
